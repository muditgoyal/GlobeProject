# %%
# No warnings
import warnings
warnings.filterwarnings('ignore') # Filter out warnings

# No warnings
import warnings
warnings.filterwarnings('ignore') # Filter out warnings

# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB # Gaussian Naive Bays
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier

import xgboost as xgb

# Plot styling
sns.set(style='white', context='notebook', palette='deep')
plt.rcParams[ 'figure.figsize' ] = 9 , 5

# %% [markdown]
# ### Beginning playing around with the D Survey Data

# %%
d_cleaned = pd.read_csv("data/cleaned/D_Survey_All.csv").drop("Unnamed: 0", axis=1)

# %%
# Categorizing by the different "major activity" with which your work is involved
general_administration = d_cleaned[d_cleaned['D129']==1]
finance = d_cleaned[d_cleaned['D129']==2]
accounting = d_cleaned[d_cleaned['D129']==3]
human_resources = d_cleaned[d_cleaned['D129']==4]
production_manufacturing = d_cleaned[d_cleaned['D129']==5]
purchasing = d_cleaned[d_cleaned['D129']==6]
transporation = d_cleaned[d_cleaned['D129']==7]
inventory_mgmt = d_cleaned[d_cleaned['D129']==8]
engineering = d_cleaned[d_cleaned['D129']==9]
research_dev = d_cleaned[d_cleaned['D129']==10]
staff_support = d_cleaned[d_cleaned['D129']==11]
facilities_mgmt = d_cleaned[d_cleaned['D129']==12]
sales_marketing = d_cleaned[d_cleaned['D129']==13]
it_mgmt = d_cleaned[d_cleaned['D129']==14]
other = d_cleaned[d_cleaned['D129']==15]

# Categorizing by gender
males = d_cleaned[d_cleaned['D131']==1]
females = d_cleaned[d_cleaned['D129']==2]

# %%
d_cleaned.groupby('couname').mean()
# Out:
#                  PH3COUNTRY    industry   ceocode        D1        D2  \
# couname
# Azerbaijan             31.0  423.560000  1.506667  5.186667  4.226667
# Brazil                 76.0  409.688889  1.777778  6.066667  2.155556
# China                 156.0  421.655405  1.945946  5.972973  2.567568
# Estonia               233.0  470.180556  1.680556  5.222222  2.236111
# Germany               276.0  368.621622  1.594595  5.864865  2.243243
# Greece                300.0  463.685714  1.457143  6.457143  2.028571
# Guatemala             320.0  403.055556  1.555556  5.861111  2.666667
# India East            357.0  363.600000  1.800000  6.133333  3.200000
# India Northeast       356.0  494.880000  1.880000  5.440000  3.040000
# Mexico                484.0  397.388889  2.000000  6.055556  2.240741
# Netherlands           528.0  476.000000  1.677966  5.322034  2.203390
# Nigeria               566.0  530.928571  1.660714  5.857143  2.964286
# ...

# %%
GEI = pd.DataFrame()
countries = ['Azerbaijan', 'Brazil', 'China', 'Estonia', 'Germany', 'Greece', 
           'Guatemala', 'India', 'Mexico', 
           'Netherlands', 'Nigeria', 'Peru', 'Romania', 'Slovenia', 'Spain', 
           'Taiwan', 'Turkey', 'USA']
geis = [30.5, 20.3, 41.1, 54.8, 65.9, 37.1, 18.5, 28.4, 26.4, 68.1, 
       19.7, 28.4, 38.2, 52.8, 45.3, 59.5, 44.5, 83.6]
GEI['countries'] = countries
GEI['gei'] = geis
GEI
# Out:
#       countries   gei
# 0    Azerbaijan  30.5
# 1        Brazil  20.3
# 2         China  41.1
# 3       Estonia  54.8
# 4       Germany  65.9
# 5        Greece  37.1
# 6     Guatemala  18.5
# 7         India  28.4
# 8        Mexico  26.4
# 9   Netherlands  68.1
# 10      Nigeria  19.7
# 11         Peru  28.4
# 12      Romania  38.2
# 13     Slovenia  52.8
# 14        Spain  45.3
# 15       Taiwan  59.5
# 16       Turkey  44.5
# 17          USA  83.6

# %%
range_ = 83.6-18.5
range_/3
# Out:
# 21.7

# %%
GEI['gei_levels'] = [(i - 18.5) // 21.7 + 1 for i in geis]
GEI
# Out:
#       countries   gei  gei_levels
# 0    Azerbaijan  30.5         1.0
# 1        Brazil  20.3         1.0
# 2         China  41.1         2.0
# 3       Estonia  54.8         2.0
# 4       Germany  65.9         3.0
# 5        Greece  37.1         1.0
# 6     Guatemala  18.5         1.0
# 7         India  28.4         1.0
# 8        Mexico  26.4         1.0
# 9   Netherlands  68.1         3.0
# 10      Nigeria  19.7         1.0
# 11         Peru  28.4         1.0
# 12      Romania  38.2         1.0
# 13     Slovenia  52.8         2.0
# 14        Spain  45.3         2.0
# 15       Taiwan  59.5         2.0
# 16       Turkey  44.5         2.0
# 17          USA  83.6         3.0

# %%
GEI['gdp'] = []
GEI
# Out:
#       countries   gei  gei_levels    gdp
# 0    Azerbaijan  30.5         1.0  16433
# 1        Brazil  20.3         1.0  14858
# 2         China  41.1         2.0  12559
# 3       Estonia  54.8         2.0  25977
# 4       Germany  65.9         3.0  44565
# 5        Greece  37.1         1.0  24273
# 6     Guatemala  18.5         1.0   6913
# 7         India  28.4         1.0   5372
# 8        Mexico  26.4         1.0  15838
# 9   Netherlands  68.1         3.0  46241
# 10      Nigeria  19.7         1.0   5443
# 11         Peru  28.4         1.0  10942
# 12      Romania  38.2         1.0  18719
# 13     Slovenia  52.8         2.0  28110
# 14        Spain  45.3         2.0  31620
# 15       Taiwan  59.5         2.0      0
# 16       Turkey  44.5         2.0  18651
# 17          USA  83.6         3.0  52676

# %%
GEI['gdp_levels'] = [i//(52676/3) + 1 for i in GEI['gdp']]
GEI
# Out:
#       countries   gei  gei_levels    gdp  gdp_levels
# 0    Azerbaijan  30.5         1.0  16433         1.0
# 1        Brazil  20.3         1.0  14858         1.0
# 2         China  41.1         2.0  12559         1.0
# 3       Estonia  54.8         2.0  25977         2.0
# 4       Germany  65.9         3.0  44565         3.0
# 5        Greece  37.1         1.0  24273         2.0
# 6     Guatemala  18.5         1.0   6913         1.0
# 7         India  28.4         1.0   5372         1.0
# 8        Mexico  26.4         1.0  15838         1.0
# 9   Netherlands  68.1         3.0  46241         3.0
# 10      Nigeria  19.7         1.0   5443         1.0
# 11         Peru  28.4         1.0  10942         1.0
# 12      Romania  38.2         1.0  18719         2.0
# 13     Slovenia  52.8         2.0  28110         2.0
# 14        Spain  45.3         2.0  31620         2.0
# 15       Taiwan  59.5         2.0      0         1.0
# 16       Turkey  44.5         2.0  18651         2.0
# ...
